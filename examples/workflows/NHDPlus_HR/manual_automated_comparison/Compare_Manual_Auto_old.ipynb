# %% [markdown]
# # Compare Manual to Automatic Meander Characterization
#
# In this code we will compare the manual to the automatic detection
#
#
# ## Start Script
# ### Importing Packages

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib ipympl

# %%
# Importing Packages
import os
import time
import copy
import numpy as np
import pandas as pd
import pyproj
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from IPython.display import Image, display, HTML
from joblib import Parallel, delayed
import plotly.io as pio
import ipywidgets as widgets
from IPython.display import display
from scipy.spatial import Delaunay
from scipy.spatial.distance import euclidean

# Importing pyMeander Packages
from WigglyRivers import RiverDatasets
from WigglyRivers import RiverFunctions as RF
from WigglyRivers import ExtractNHDPlusHRData as NHD
from WigglyRivers.utilities import utilities as utl
from WigglyRivers.utilities import filesManagement as FM
from WigglyRivers import Logger
from WigglyRivers import WaveletTreeFunctions as WTFunc
from WigglyRivers import CompareMeanders as CM

# %%
def convert_str_float_list_vector(x_val):
    x_val = x_val.replace('[', '').replace(']', '').replace('\n', ',').replace(
        ' ', ',').split(',')
    x_val = np.array([float(x) for x in x_val if x != ''])
    return  x_val

# %%
# Start Logger
logger = Logger(console=True)
# Out:
# 2024-01-24 11:26:27,535[INFO] set_logger: Starting log

# %%
# Parameters
path_projects = './meander_comparison/characterization/manual_corrected/'
projects = utl.get_folders(path_projects)
path_projects_all = [f'{path_projects}{p}/' for p in projects]
path_projects_c = './projects/old_characterization/with_automatic/'
path_projects_out = [f'{path_projects_c}{p}/' for p in projects]

print(projects)

# Current projection of information
projection = 'esri:102003'
# Out:
# ['0104', '0106', '0107', '0307', '0406', '0408', '0412', '0504', '0510', '0601', '0701', '0708', '0714', '0803', '0808', '0904', '1002', '1006', '1009', '1017', '1021', '1030', '1108', '1110', '1113', '1202', '1206', '1208', '1211', '1305', '1307', '1402', '1404', '1406', '1701']

# %% [markdown]
# ### Test Manual Selection

# %%
# Extract Example
project = projects[0]

# %% [markdown]
# ### Perform Automatic Detection

# %%
# Select project to load
for project in projects:
    try:
        i_p = projects.index(project)
    except ValueError:
        raise ValueError(f'Project "{project}" not found')

    project_to_load = path_projects_all[i_p]
    print('Set project to load: ' + project_to_load)
    rivers = RiverDatasets(logger=logger)
    river_network_file = f'{project_to_load}/rivers.hdf5'
    rivers.load_river_network(
        river_network_file,
        fn_meanders_database=f'{project_to_load}/meander_database.csv')
    id_rivers = rivers.id_values

    # Select River
    id_river = id_rivers[0]
    river = rivers[id_river]
    # -----------------------------
    # Calculate Smooth Coordinates
    # -----------------------------
    rivers[id_river].calculate_smooth(poly_order=2, gaussian_window=1,)
    # -----------------------------
    # Calculate Curvature
    # -----------------------------
    rivers[id_river].calculate_curvature(data_source='smooth') 
    # -----------------------------
    # Extract CWT tree
    # -----------------------------
    rivers[id_river].extract_cwt_tree()
    # -----------------------------
    # Prune by peak power
    # -----------------------------
    rivers[id_river].prune_tree_by_peak_power()
    # -----------------------------
    # Add meander to database
    # -----------------------------
    rivers[id_river].add_meanders_from_tree_scales()
    # -----------------------------
    # Save database
    # -----------------------------
    rivers.save_rivers(
        path_out=f'{path_projects_c}{project}/',
        file_name='rivers_automatic.hdf5',
        file_name_meander_database='meander_database_all.csv')
    aaaa
# Out:
# 2024-01-24 14:23:01,855[INFO] info: Start Logger in RiverDatasets
# Set project to load: ./meander_comparison/characterization/manual_corrected/0104/
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 12
#      10 rivers = RiverDatasets(logger=logger)
#      11 river_network_file = f'{project_to_load}/rivers.hdf5'
# ---> 12 rivers.load_river_network(
#      13     river_network_file,
#      14     fn_meanders_database=f'{project_to_load}/meander_database.csv')
#      15 id_rivers = rivers.id_values
#      17 # Select River
#
# File d:\work\myrepos\wigglyrivers\WigglyRivers\rivers\RiversNetwork.py:1184, in RiverDatasets.load_river_network(self, path_file, headwaters_comid, fn_tree_scales, fn_tree_scales_database, fn_meanders_database, kwargs_resample, scale_by_width, **kwargs)
#    1182                 except KeyError:
#    1183                     tree_id = -1
# -> 1184                 self.rivers[hw_r].add_meander(
#    1185                     id_meander, idx_start, idx_end,
#    1186                     sk=sk, fl=fl, automatic_flag=automatic_flag,
#    1187                     inflection_flag=inflection_flag,
#    1188                     tree_id=tree_id)
#    1192     # TODO: Correct the loading of poly and zc_lines
#    1193     # Add Tree Scales database
#    1194     # if cwt_trees_file is not None:
#    (...)
#    1199
#    1200 # Sort Rivers from longest to shortest
#    1201 id_rivers = self.rivers['id_values']
#
# File d:\work\myrepos\wigglyrivers\WigglyRivers\rivers\RiversNetwork.py:3273, in RiverTransect.add_meander(self, id_meander, ind_start, ind_end, metrics, sk, fl, automatic_flag, inflection_flag, tree_id, x_inf, y_inf, s_inf)
#    3269 # -------------------------
#    3270 # Add meander
#    3271 # -------------------------
#    3272 self.id_meanders.append(id_meander)
# -> 3273 meander = Meander(s, x, y, z, ind_start, ind_end,
#    3274                   so=so, x_o=x_o, y_o=y_o,
#    3275                   ind_start_o=idx_start_o, ind_end_o=idx_end_o,
#    3276                   c=c, metrics=metrics, sk=sk, fl=fl, comid=comid,
#    3277                   automatic_flag=automatic_flag,
#    3278                   inflection_flag=inflection_flag, tree_id=tree_id)
#    3279 if len(self._calc_vars) == 0:
#    3280     self._calc_vars = meander.calc_vars
#
# File d:\work\myrepos\wigglyrivers\WigglyRivers\rivers\RiversNetwork.py:3502, in Meander.__init__(self, s, x, y, z, ind_start, ind_end, c, sk, fl, comid, x_o, y_o, ind_start_o, ind_end_o, so, metrics, calculations, automatic_flag, inflection_flag, tree_id)
#    3500 plt.gca().set_aspect('equal', adjustable='box')
#    3501 plt.show()
# -> 3502 aaa
#    3504 # Calculate curvature
#    3505 if c is None:
#
# NameError: name 'aaa' is not defined

# %%
# Open databases
bounds_array_str = 'extended'
data_link = {}
for i_m, project in enumerate(projects):
    print(project)
    try:
        i_p = projects.index(project)
    except ValueError:
        raise ValueError(f'Project "{project}" not found')

    project_to_load = path_projects_out[i_p]
    # Load Meander database
    database = FM.load_data(
        f'{project_to_load}/meander_database_{bounds_array_str}_all.csv',
        pandas_dataframe=True)

    # Check common meanders between automatic and manual
    auto_df = database[database['automatic_flag'] == 1]
    manual_df = database[database['automatic_flag'] == 0]

    # Compare manual to automatic meanders
    database = CM.extract_closet_meanders(
        manual_df, auto_df, link_x='x_o', link_y='y_o')
    
    # Save database
    FM.save_data(database, path_output=f'{project_to_load}/',
                 file_name=f'compare_manual_auto_{bounds_array_str}.csv')
    
    if i_m == 0:
        database_all = database.copy()
    else:
        database_all = pd.concat([database_all, database], ignore_index=True)

FM.save_data(database_all, path_output=f'./projects/meander_comparison/old/',
                file_name=f'compare_manual_auto_{bounds_array_str}_all.csv')
# Out:
# 0104
# 0106
# 0107
# 0307
# 0406
# 0408
# 0412
# 0504
# 0510
# 0601
# 0701
# 0708
# 0714
# 0803
# 0808
# 0904
# 1002
# 1006
# 1009
# 1017
# 1021
# 1030
# 1108
# 1110
# 1113
# 1202
# 1206
# 1208
# 1211
# 1305
# 1307
# 1402
# 1404
# 1406
# 1701

# %%
# Look comparison
bounds_array_str = 'extended'
utl.cr_folder('../results/wavelet_analysis/comparison_meanders/')
data_link = FM.load_data('./projects/meander_comparison/old/'
                         f'compare_manual_auto_{bounds_array_str}_all.csv',
                         pandas_dataframe=True)

classification = ['I', 'II', 'III', 'IV']
c_colors = ['r', 'g', 'b', 'y']

sns.set(font_scale=2)
# Plot hexbin
hexplot = sns.jointplot(data=data_link, x='f_oa', y='f_om', kind='hex',
              color='#2b8cbe',
              xlim=(-0.05, 1.05),
              ylim=(-0.05, 1.05), height=10)
plt.axhline(y=0.8, color='k', linestyle='--')
plt.axvline(x=0.8, color='k', linestyle='--')
plt.xlabel(r'$F_{OA}=N_O/N_A$')
plt.ylabel(r'$F_{OM}=N_O/N_M$')
plt.subplots_adjust(left=0.2, right=0.8, top=0.8, bottom=0.2)
cbar_ax = hexplot.fig.add_axes([.82, .20, .02, .5])
plt.colorbar(cax=cbar_ax)
plt.show()
# plt.savefig('../results/wavelet_analysis/comparison_meanders/hexbin.png',
#             dpi=300)
# plt.savefig('../results/wavelet_analysis/comparison_meanders/hexbin.pdf',
#             dpi=300)
# plt.close('all')

# Plot summary of the classification
data_plot = data_link.loc[:, ['so_1', 'Zone']]
dp_2 = data_plot.groupby(['Zone']).count()
dp = data_plot.pivot_table(values='Zone',
                           index=['so_1'], columns=['Zone'],
                           aggfunc=np.size)
colors = [
    '#a6cee3',
    '#1f78b4',
    '#b2df8a',
    '#33a02c',
]
total = len(data_plot)
title = (f'Classification (N={total})\n '
         f'I={dp_2.loc[1, "so_1"]/total*100:.1f}%, '
         f'II={dp_2.loc[2, "so_1"]/total*100:.1f}%, '
         f'III={dp_2.loc[3, "so_1"]/total*100:.1f}%, '
         f'IV={dp_2.loc[4, "so_1"]/total*100:.1f}%')
dp.plot(kind='bar', stacked=True, figsize=(10, 8), color=colors,
        title=title)
plt.legend(title=None, frameon=False)
plt.xlabel('Stream Order')
plt.ylabel('Count')
plt.show()
# plt.savefig('./results/wavelet_analysis/comparison_meanders/'
#             'classification.png', dpi=300)
# plt.savefig('./results/wavelet_analysis/comparison_meanders/'
#             'classification.pdf', dpi=300)
# plt.close('all')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
subset_df['huc04_n_2']
# Out:
# 2       0104_0
# 4       0104_0
# 6       0104_0
# 7       0104_0
# 8       0104_0
#          ...
# 1269    1701_0
# 1271    1701_0
# 1272    1701_0
# 1273    1701_0
# 1274    1701_0
# Name: huc04_n_2, Length: 864, dtype: object

# %%
# Look at individual meanders 
bounds_array_str = 'extended'
utl.cr_folder('../results/wavelet_analysis/comparison_meanders/')
data_link = FM.load_data('./projects/meander_comparison/old/'
                         f'compare_manual_auto_{bounds_array_str}_all.csv',
                         pandas_dataframe=True)

# Extract in specific Zone 1
subset_df = data_link[data_link['Zone'] == 3]
i_m = 0
x_m = convert_str_float_list_vector(subset_df['x_1'].values[i_m]) 
y_m = convert_str_float_list_vector(subset_df['y_1'].values[i_m])

x_a = convert_str_float_list_vector(subset_df['x_2'].values[i_m])
y_a = convert_str_float_list_vector(subset_df['y_2'].values[i_m])

plt.figure(figsize=(8, 8))
plt.plot(x_m, y_m, 'k', label='Manual')
plt.plot(x_a, y_a, 'ro--', label='Auto')
plt.gca().set_aspect('equal', adjustable='box')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
